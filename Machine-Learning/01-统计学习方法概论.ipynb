# %% [markdown]
# ## 分类
# ### 基本分类
# 1. 监督学习
# 2. 无监督学习
# 3. 强化学习
# 4. 半监督学习与主动学习
# ### 按模型分类
# 1. 概率模型/非概率模型
# 2. 线性模型/非线性模型
# 3. 参数化模型/非参数化模型
# ### 按算法分类
# 1. 在线学习/批量学习
# ### 按照技巧分类
# 1. 贝叶斯
# 2. 核方法
#
# ## 三要素
# 方法 = 模型 + 策略 + 算法
